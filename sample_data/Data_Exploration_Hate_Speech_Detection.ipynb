# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import numpy as np

# %%
data = pd.read_csv('sample_data/labeled_data.csv')

def replace_number(text):
  if text == 1:
    return 'Offensive'
  elif text == 2:
    return 'Neither'
  else:
    return 'Hate'

data['class'] = data['class'].apply(replace_number)

# %%
#Check and handle NaH row
data.dropna(inplace = True)

# %%
#Bar Chart

sns.countplot(data = data, x = "class", color = 'purple')
plt.xlabel('Offensive Level')
plt.ylabel('Number of Posts/Comments')
plt.title('Distribution of Hate Speeches')
# Out:
# Text(0.5, 1.0, 'Distribution of Hate Speeches')

# %%
#Word count by offensive level

data["word_count"] = data["tweet"].apply(lambda x: len(str(x).split()))
sns.boxplot(data = data, x = 'class', y = 'word_count', color = 'purple', palette='Set2', flierprops={'marker': 'o', 'markersize': 4, 'markerfacecolor': 'black'})
plt.xlabel('Offensive Level')
plt.ylabel('Frequency')
plt.title('Box Plot of Hate Speeches')
plt.show()
# Out:
# <ipython-input-33-2883901d0c56>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = data, x = 'class', y = 'word_count', color = 'purple', palette='Set2', flierprops={'marker': 'o', 'markersize': 4, 'markerfacecolor': 'black'})

# %%
#WordCloud

all_text = ' '.join([text for text in data['tweet'].astype(str)])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
#Violin Plot

plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='class', y='word_count', palette='Set2')
plt.xlabel('Offensive Level')
plt.ylabel('Frequency')
plt.title('Violin Plot of Hate Speeches')
plt.show()
# Out:
# <ipython-input-40-1f748bf0aee0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data, x='class', y='word_count', palette='Set2')
